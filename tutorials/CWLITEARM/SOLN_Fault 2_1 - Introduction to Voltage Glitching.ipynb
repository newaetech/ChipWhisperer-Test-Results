# %% [markdown]
# # Part 2, Topic 1: Introduction to Voltage Glitching (MAIN)

# %% [markdown]
# ---
# NOTE: This lab references some (commercial) training material on [ChipWhisperer.io](https://www.ChipWhisperer.io). You can freely execute and use the lab per the open-source license (including using it in your own courses if you distribute similarly), but you must maintain notice about this source location. Consider joining our training course to enjoy the full experience.
#
# ---

# %% [markdown]
# **SUMMARY:** *Similarly to clock glitching, inserting brief glitches into the power line of an embedded device can result in skipped instructions and corrupted results. Besides providing a more reliable glitch on some targets when compared to clock glitching, voltage glitching also has the advanatage that the Vcc pins on chips are always accessable. This won't be covered in this course, but it can also be used to glitch a device asynchronous to its clock.*
#
# **LEARNING OUTCOMES:**
#
# * Understanding voltage glitch settings
# * Building a voltage glitch and crash map.
# * Modifying glitch circuit to increase glitch success

# %% [markdown]
# ## Voltage Glitch Hardware
#
# The ChipWhisperer uses the same hardware block for both voltage and clock glitching, with the only difference being where the glitch output is routed to. Instead of routing to HS2, voltage glitching is performed by routing the glitch to either the `glitch_hp` transistor or the `glitch_lp` transistor. This can be done via the following API calls:
#
# ```python
# scope.io.glitch_hp = True #enable HP glitch
# scope.io.glitch_hp = False #disable LP glitch
# scope.io.glitch_lp = True #enable LP glitch
# scope.io.glitch_lp = False #disable LP glitch
# ```
#
# While the hardware block are the same, you'll need to change how it's configued. You wouldn't want to try routing `"clock_xor"` to the glitch transistor and oscillate Vcc like the device's clock! Instead, the following two output settings are best suited to voltage glitching:
#
# 1. `"glitch_only"` - insert a glitch for a portion of a clock cycle based on `scope.glitch.width` and `scope.glitch.offset`
# 1. `"enable_only"` - insert a glitch for an entire clock cycle
#
# Typically, the `"enable_only"` setting will be too powerful for most devices. One situation where it outshines `"glitch_only"` is in glitching asychronous to the target's clock. An example of this is glitching a target with an internal clock. In this case, the ChipWhisperer's clock can be boosted far above the target's to insert a precise glitch, with `repeat` functioning as `width` and `ext_offset` functioning as `offset`.
#
# ### Voltage Glitching vs. Clock Glitching
#
# Voltage glitching has some obvious benefits over clock glitching, such as working for a wider varitey of targets, but its downsides are less obvious. One of the biggest is how much it depends on the actual glitch circuit itself. With clock glitching, it's relatively easy to insert a glitch - there's nothing external trying to keep the clock at a certain voltage level. This is very different for a target's power pins. When we try to drop the power pin to ground, there's a lot of stuff fighting us to keep the power pin at the correct voltage, such as decoupling capacitors, bulk supply capacitors, and the voltage regulator supplying the voltage. This means when we make small changes to the glitch circuit, the glitch settings and even our ability to insert a glitch at all completely change! Consider glitching a target on the CW308 UFO board. If you switch your coaxial cable length from 20cm to 40 cm, you'll need to find entirely new glitch settings to repeat the attack (if it's still even possible). This is quite easy to see on an oscilloscope or  using the ChipWhisperer's ADC: longer cables and lower valued shunt resistors will make the glitch less sharp and increase ringing.
#
# While your first thought might be to go for as sharp a glitch as possible, this often won't result in a high glitch success rate. If you're unable to find any working glitches with your current setup, it might be worth changing you hardware setup a bit. For example, on the ChipWhisperer Lite 1 part, you can desolder SJ5 and solder header pins to JP6. Even just connecting these pins with a jumper will have different glitch behaviour than with a soldered SJ5.
#
# You can refer to the training slides for more information about finding good glitch settings, as well as more on the theory side of voltage glitching.
#
# ### The Lab
#
# To introduce you to volatge glitching and find some settings, we're going to walk back through the clock glitching loop lab. You may want to capture some power traces while you're first experimenting with glitches to see what effects different glitch widths have on the power trace. Another thing to keep in mind is that targets often won't tolerate the Vcc pin dropping for an extended period of time without crashing - once you see the target start to crash, you won't see much else with larger widths.
#
# One thing you might have to change is the glitch repeat value. Depending on how wide your glitch is, the voltage at the power pin may not recover by the time the next glitch is inserted. This can have to effect of increasing subsequent glitches' strength, which may or may not be desirable. Since glitches inserted with repeat > 1 have different strength, it's a good idea to scan through ext_offset as well.
#
# ###  Higher Frequency Glitching
#
# The XMEGA target, and to a lesser extent the STM32F3, is very difficult to glitch with the default ChipWhisperer settings. Try bumping the clock frequency to 24MHz for the STM32 or 32MHz for the XMEGA and use a repeat 5-10 with both the high power and low power glitches active. You'll need to adjust the baud rate by the same proportion as the clock. This will increase the glitch precision, as the glitch width/offset step is based on the target clock, and may decrease the stability of the target.
#
# Another setup that seems to work with the XMEGA is SJ5 unsoldered, JP6 jumpered, high+low power glitch, 32MHz, and repeat=5.
#
# The ChipWhisperer Husky, with its PLL based glitching system, can typically glitch targets without needing to change the target's frequency.
#
# ### Disabling Logging
#
# When glitching (or just running normally in earlier labs), you may have seen various warnings from loggers ChipWhisperer uses. This often has useful information, especially if things don't work right, but for voltage
# glitching especially, it mostly clutters up any print output you have. As such, we'll disable logging for the voltage glitching labs:
#
# ```python
# cw.set_all_log_levels(cw.logging.CRITICAL)
# ```
#
# You can reenable logging via
#
# ```python
# cw.set_all_log_levels(cw.logging.WARNING)
# ```

# %%
SCOPETYPE = 'OPENADC'
PLATFORM = 'CWLITEARM'
SS_VER = 'SS_VER_2_1'

allowable_exceptions = None
VERSION = 'HARDWARE'
CRYPTO_TARGET = 'TINYAES128C'

# %%
#!/usr/bin/env python
# coding: utf-8

# In[ ]:


import chipwhisperer as cw

try:
    if not scope.connectStatus:
        scope.con()
except NameError:
    scope = cw.scope(hw_location=(5, 3))

try:
    if SS_VER == "SS_VER_2_1":
        target_type = cw.targets.SimpleSerial2
    elif SS_VER == "SS_VER_2_0":
        raise OSError("SS_VER_2_0 is deprecated. Use SS_VER_2_1")
    else:
        target_type = cw.targets.SimpleSerial
except:
    SS_VER="SS_VER_1_1"
    target_type = cw.targets.SimpleSerial

try:
    target = cw.target(scope, target_type)
except:
    print("INFO: Caught exception on reconnecting to target - attempting to reconnect to scope first.")
    print("INFO: This is a work-around when USB has died without Python knowing. Ignore errors above this line.")
    scope = cw.scope(hw_location=(5, 3))
    target = cw.target(scope, target_type)


print("INFO: Found ChipWhisperer😍")


# In[ ]:


if "STM" in PLATFORM or PLATFORM == "CWLITEARM" or PLATFORM == "CWNANO":
    prog = cw.programmers.STM32FProgrammer
elif PLATFORM == "CW303" or PLATFORM == "CWLITEXMEGA":
    prog = cw.programmers.XMEGAProgrammer
elif "neorv32" in PLATFORM.lower():
    prog = cw.programmers.NEORV32Programmer
elif PLATFORM == "CW308_SAM4S" or PLATFORM == "CWHUSKY":
    prog = cw.programmers.SAM4SProgrammer
else:
    prog = None


# In[ ]:


import time
time.sleep(0.05)
scope.default_setup()

def reset_target(scope):
    if PLATFORM == "CW303" or PLATFORM == "CWLITEXMEGA":
        scope.io.pdic = 'low'
        time.sleep(0.1)
        scope.io.pdic = 'high_z' #XMEGA doesn't like pdic driven high
        time.sleep(0.1) #xmega needs more startup time
    elif "neorv32" in PLATFORM.lower():
        raise IOError("Default iCE40 neorv32 build does not have external reset - reprogram device to reset")
    elif PLATFORM == "CW308_SAM4S" or PLATFORM == "CWHUSKY":
        scope.io.nrst = 'low'
        time.sleep(0.25)
        scope.io.nrst = 'high_z'
        time.sleep(0.25)
    else:  
        scope.io.nrst = 'low'
        time.sleep(0.05)
        scope.io.nrst = 'high_z'
        time.sleep(0.05)
# Out:
# INFO: Found ChipWhisperer😍
# scope.gain.mode                          changed from low                       to high
# scope.gain.gain                          changed from 0                         to 30
# scope.gain.db                            changed from 5.5                       to 24.8359375
# scope.adc.basic_mode                     changed from low                       to rising_edge
# scope.adc.samples                        changed from 24400                     to 5000
# scope.adc.trig_count                     changed from 11021999                  to 22083991
# scope.clock.adc_src                      changed from clkgen_x1                 to clkgen_x4
# scope.clock.adc_freq                     changed from 29538459                  to 30413875
# scope.clock.adc_rate                     changed from 29538459.0                to 30413875.0
# scope.clock.clkgen_div                   changed from 1                         to 26
# scope.clock.clkgen_freq                  changed from 192000000.0               to 7384615.384615385
# scope.io.tio1                            changed from serial_tx                 to serial_rx
# scope.io.tio2                            changed from serial_rx                 to serial_tx
# scope.io.hs2                             changed from None                      to clkgen
# scope.glitch.mmcm_locked                 changed from True                      to False

# %%
# %%bash -s "$PLATFORM" "$SS_VER"
# cd ../../../firmware/mcu/simpleserial-glitch
# make PLATFORM=$1 CRYPTO_TARGET=NONE SS_VER=$2 -j
# Out:
# SS_VER set to SS_VER_2_1
# SS_VER set to SS_VER_2_1
# arm-none-eabi-gcc (15:9-2019-q4-0ubuntu1) 9.2.1 20191025 (release) [ARM/arm-9-branch revision 277599
# ]
# Copyright (C) 2019 Free Software Foundation, Inc.
# This is free software; see the source for copyin
# g conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOS
# E.
# mkdir -p objdir-CWLITEARM
# .
# Welcome to another exciting ChipWhisperer target build!!
# .
# .
# Compiling:
# Compiling:
# .
# -en     simpleserial-glitch.c ...
# Compiling:
# -en     .././simpleserial/simpleserial.c ...
# .
# .
# -en     .././hal/hal.c ...
# Compiling:
# Compiling:
# -en     .././hal//stm32f3/stm32f3_hal.c ...
# -en     .././hal//stm32f3/stm32f3_hal_lowlevel.c ...
# .
# Compiling:
# .
# -en     .././hal//stm32f3/stm32f3_sysmem.c ...
# Assembling: .././hal//stm32f3/stm32f3_startup.S
# arm-none-eabi-gcc -c -mcpu=cortex-m4 -I. -x assembler-with-cpp -mthumb -mfloat-abi=soft -fmessage-le
# ngth=0 -ffunction-sections -DF_CPU=7372800 -Wa,-gstabs,-adhlns=objdir-CWLITEARM/stm32f3_startup.lst
# -I.././simpleserial/ -I.././hal/ -I.././hal/ -I.././hal//stm32f3 -I.././hal//stm32f3/CMSIS -I.././ha
# l//stm32f3/CMSIS/core -I.././hal//stm32f3/CMSIS/device -I.././hal//stm32f4/Legacy -I.././simpleseria
# l/ -I.././crypto/ .././hal//stm32f3/stm32f3_startup.S -o objdir-CWLITEARM/stm32f3_startup.o
# -e Done!
# -e Done!
# -e Done!
# -e Done!
# -e Done!
# -e Done!
# .
# LINKING:
# -en     simpleserial-glitch-CWLITEARM.elf ...
# -e Done!
# .
# .
# Creating load file for Flash: simpleserial-glitch-CWLITEARM.hex
# Creating load file for Flash: simpleserial-glitch-CWLITEARM.bin
# arm-none-eabi-objcopy -O ihex -R .ee
# prom -R .fuse -R .lock -R .signature simpleserial-glitch-CWLITEARM.elf simpleserial-glitch-CWLITEARM
# .hex
# .
# arm-none-eabi-objcopy -O binary -R .eeprom -R .fuse -R .lock -R .signature simpleserial-glitc
# h-CWLITEARM.elf simpleserial-glitch-CWLITEARM.bin
# Creating Extended Listing: simpleserial-glitch-CWLITEARM.lss
# arm-none-eabi-objdump -h -S -z simplese
# rial-glitch-CWLITEARM.elf > simpleserial-glitch-CWLITEARM.lss
# .
# Creating Symbol Table: simpleserial-
# glitch-CWLITEARM.sym
# arm-none-eabi-nm -n simpleserial-glitch-CWLITEARM.elf > simpleserial-glitch-CWL
# ITEARM.sym
# .
# Creating load file for EEPROM: simpleserial-glitch-CWLITEARM.eep
# arm-none-eabi-objcopy -j .eeprom --set-section-flags=.eeprom="alloc,load" \
# --change-section-lma .ee
# prom=0 --no-change-warnings -O ihex simpleserial-glitch-CWLITEARM.elf simpleserial-glitch-CWLITEARM.
# eep || exit 0
# Size after:
#    text	   data	    bss	    dec	    hex	filename
#    5524	      8	   1368	   6900	   1af4	simpleseria
# l-glitch-CWLITEARM.elf
# +--------------------------------------------------------
# + Default target does full rebuild each time.
# + Specify buildtarget == allquick == to avoid full rebuild
# +----------------------------------------
# ----------------
# +--------------------------------------------------------
# + Built for platform CW-Lite Arm \(STM32F3
# \) with:
# + CRYPTO_TARGET = NONE
# + CRYPTO_OPTIONS =
# +--------------------------------------------------------

# %%
fw_path = "../../../firmware/mcu/simpleserial-glitch/simpleserial-glitch-{}.hex".format(PLATFORM)
cw.program_target(scope, prog, fw_path)
if SS_VER=="SS_VER_2_1":
    target.reset_comms()
# Out:
# Detected known STMF32: STM32F302xB(C)/303xB(C)
# Extended erase (0x44), this can take ten seconds or more
# Attempting to program 5531 bytes at 0x8000000
# STM32F Programming flash...
# STM32F Reading flash...
# Verified flash OK, 5531 bytes

# %%
def reboot_flush():
    reset_target(scope)
    target.flush()

if scope._is_husky is False:
    if PLATFORM == "CWLITEXMEGA":
        scope.clock.clkgen_freq = 32E6
        if SS_VER=='SS_VER_2_1':
            target.baud = 230400*32/7.37
        else:
            target.baud = 38400*32/7.37
    elif (PLATFORM == "CWLITEARM") or ("F3" in PLATFORM):
        scope.clock.clkgen_freq = 24E6
        if SS_VER=='SS_VER_2_1':
            target.baud = 230400*24/7.37
        else:
            target.baud = 38400*24/7.37
        time.sleep(0.1)

# %%
reboot_flush()
scope.arm()
target.simpleserial_write("g", bytearray([]))
scope.capture()
val = target.simpleserial_read_witherrors('r', 4, glitch_timeout=10)#For loop check
valid = val['valid']
if valid:
    response = val['payload']
    raw_serial = val['full_response']
    error_code = val['rv']

print(val)
# Out:
# {'valid': True, 'payload': CWbytearray(b'c4 09 00 00'), 'full_response': CWbytearray(b'00 72 04 c4 09 00 00 15 00'), 'rv': bytearray(b'\x00')}

# %%
gc = cw.GlitchController(groups=["success", "reset", "normal"], parameters=["width", "offset", "ext_offset", "tries"])
gc.display_stats()
# Out:
# IntText(value=0, description='success count:', disabled=True)
# IntText(value=0, description='reset count:', disabled=True)
# IntText(value=0, description='normal count:', disabled=True)
# FloatSlider(value=0.0, continuous_update=False, description='width setting:', disabled=True, max=10.0, readout…
# FloatSlider(value=0.0, continuous_update=False, description='offset setting:', disabled=True, max=10.0, readou…
# FloatSlider(value=0.0, continuous_update=False, description='ext_offset setting:', disabled=True, max=10.0, re…
# FloatSlider(value=0.0, continuous_update=False, description='tries setting:', disabled=True, max=10.0, readout…

# %%
gc.glitch_plot(plotdots={"success":"+g", "reset":"xr", "normal":None}, bufferlen=int(10E6))
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='be8ac685-74b3-419f-b5ad-7c4874595873'>
#   <div id="ff2f35e9-f15e-4257-9f99-82b05c982210" data-root-id="be8ac685-74b3-419f-b5ad-7c4874595873" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"76d305a9-a4c6-4288-a208-40a5f8cb6125":{"version":"3.6.3","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"be8ac685-74b3-419f-b5ad-7c4874595873"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"de289bf9-4f52-427e-b4b1-f8f2c24545db","attributes":{"plot_id":"be8ac685-74b3-419f-b5ad-7c4874595873","comm_id":"1e59ec27226e46cca5d332725ad2e82c","client_comm_id":"9d949e61308540c8afef18ffb3df0024"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_rendered","kind":"Any","default":false},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","d ...
#   var render_items = [{"docid":"76d305a9-a4c6-4288-a208-40a5f8cb6125","roots":{"be8ac685-74b3-419f-b5ad-7c4874595873":"ff2f35e9-f15e-4257-9f99-82b05c982210"},"root_ids":["be8ac685-74b3-419f-b5ad-7c4874595873"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# :DynamicMap   []
#    :Overlay
#       .Points.I  :Points   [width,offset]
#       .Points.II :Points   [width,offset]

# %% [markdown]
# Next, we'll setup the glitch. The main differences here compared to clock glitching is the use of `scope.io.glitch_lp/hp`, which activates the transistors used for voltage, and `scope.glitch.output = 'glitch_only'`, which sends the glitch output to the transistors instead of xoring it with the clock like with clock glitching.

# %%
if scope._is_husky:
    scope.glitch.enabled = True
    scope.glitch.clk_src = "pll"
    scope.io.glitch_hp = True
    scope.io.glitch_lp = False
else:
    scope.glitch.clk_src = "clkgen" # set glitch input clock
scope.glitch.output = "glitch_only" # glitch_out = clk ^ glitch
scope.glitch.trigger_src = "ext_single" # glitch only after scope.arm() called
if PLATFORM == "CWLITEXMEGA":
    scope.io.glitch_lp = True
    scope.io.glitch_hp = True
elif PLATFORM == "CWLITEARM":
    scope.io.glitch_lp = True
    scope.io.glitch_hp = True
elif PLATFORM == "CW308_STM32F3":
    scope.io.glitch_hp = True
    scope.io.glitch_lp = True

# %% [markdown]
# Some tips for finding good glitches:
#
# 1. There's a lot of stuff fighting our glitch this time - unlike the clock line, the Vcc rail isn't supposed to oscillate! As such shorter glitches will have no effect. Often, good widths will be just below when the target starts consistantly crashing, so a good strategy is to find the minimum width where crashes always happen, then backing the width off a bit.
# 1. The repeat parameter behaves very differently than with voltage glitching - at the boosted clock rate, the Vcc often won't recover before the next glitch. Try different repeat values as well.
# 1. We've built in a success/reset measurement into the glitch loop. Once you've found some glitch spots, this will help you evaluate which ones are best for your target.
#
# It can take a very long time to do go through the full search space, so you may want to stop after you get a certain number of succeses. By default here, it will be 1, but you may want to change it to 10, 20, or go even higher.

# %%
MAX_SUCCESSES = 100000

# %%
num_tries = 1 # increase to get better glitch stats
gc.set_range("tries", 1, num_tries)
if scope._is_husky:
    gc.set_range("width", 1850, 3000)
    gc.set_range("offset", 1800, 3000)
    gc.set_global_step([50]) # reduce to fine tune glitching
    
    gc.set_step("ext_offset", 1)
    gc.set_range("ext_offset", 10, 50)
    scope.glitch.repeat = 1
    scope.adc.lo_gain_errors_disabled = True
    scope.adc.clip_errors_disabled = True
elif PLATFORM=="CWLITEXMEGA":
    gc.set_range("width", 43.5, 47.8)
    gc.set_range("offset", -48, -10)
    gc.set_range("ext_offset", 7, 10)
    gc.set_global_step(0.4)
    gc.set_step("ext_offset", 1)
    scope.glitch.repeat = 11
elif PLATFORM == "CWLITEARM":
    #should also work for the bootloader memory dump
    gc.set_range("width", 34, 36)
    gc.set_range("offset", -40, 10)
    gc.set_range("ext_offset", 4, 30)
    gc.set_global_step(0.4)
    gc.set_step("ext_offset", 1)
    scope.glitch.repeat = 7
elif PLATFORM == "CW308_STM32F3":
    #these specific settings seem to work well for some reason
    #also works for the bootloader memory dump
    gc.set_range("ext_offset", 4, 30)
    gc.set_range("width", 47.6, 49.6)
    gc.set_range("offset", -19, -21.5)
    gc.set_global_step(0.4)
    gc.set_step("ext_offset", 1)
    scope.glitch.repeat = 5

gc.set_step("tries", 1)

# %%
import struct

#disable logging
cw.set_all_log_levels(cw.logging.CRITICAL)

scope.adc.timeout = 0.5

reboot_flush()
loff = scope.glitch.offset
lwid = scope.glitch.width
total_successes = 0
successes = 0
resets = 0
for glitch_setting in gc.glitch_values():
    scope.glitch.offset = glitch_setting[1]
    scope.glitch.width = glitch_setting[0]
    scope.glitch.ext_offset = glitch_setting[2]
    #print(scope.glitch.ext_offset)
    if glitch_setting[3] == 1:
        total_successes += successes
        if (successes > 0):
            print("successes = {}, resets = {}, offset = {}, width = {}, ext_offset = {}".format(successes, resets, scope.glitch.offset, scope.glitch.width, scope.glitch.ext_offset))
            total_successes += successes
        successes = 0
        resets = 0
        #if total_successes > MAX_SUCCESSES:
        #    break
    target.flush()
    if scope.adc.state:
        # can detect crash here (fast) before timing out (slow)
        #print("Trigger still high!")
        gc.add("reset")

        #Device is slow to boot?
        reboot_flush()
        resets += 1

    scope.arm()

    #Do glitch loop
    target.simpleserial_write("g", bytearray([]))

    ret = scope.capture()

    scope.io.vglitch_reset()
    if ret:
        #print('Timeout - no trigger')
        gc.add("reset")
        resets += 1

        #Device is slow to boot?
        reboot_flush()

    else:
        val = target.simpleserial_read_witherrors('r', 4, glitch_timeout=10, timeout=50)#For loop check
        if val['valid'] is False:
            gc.add("reset")
            reboot_flush()
            resets += 1
            #print(val)
        else:
            gcnt = struct.unpack("<I", val['payload'])[0]

            if gcnt != 2500: #for loop check
                gc.add("success")
                #print((scope.glitch.width, scope.glitch.offset, scope.glitch.ext_offset))
                successes += 1
            else:
                gc.add("normal")

print("Done glitching")
#enable logging
cw.set_all_log_levels(cw.logging.WARNING)
# Out:
# successes = 1, resets = 0, offset = 1.171875, width = 33.984375, ext_offset = 15
# successes = 1, resets = 0, offset = 1.5625, width = 33.984375, ext_offset = 19
# successes = 1, resets = 0, offset = 1.953125, width = 33.984375, ext_offset = 18
# successes = 1, resets = 0, offset = 1.953125, width = 33.984375, ext_offset = 20
# successes = 1, resets = 0, offset = 2.34375, width = 33.984375, ext_offset = 20
# successes = 1, resets = 0, offset = 2.734375, width = 33.984375, ext_offset = 18
# successes = 1, resets = 0, offset = 3.515625, width = 33.984375, ext_offset = 15
# successes = 1, resets = 0, offset = 3.90625, width = 33.984375, ext_offset = 15
# successes = 1, resets = 0, offset = 4.296875, width = 33.984375, ext_offset = 16
# successes = 1, resets = 0, offset = 5.078125, width = 33.984375, ext_offset = 15
# successes = 1, resets = 0, offset = 5.46875, width = 33.984375, ext_offset = 16
# successes = 1, resets = 0, offset = 5.859375, width = 33.984375, ext_offset = 15
# successes = 1, resets = 0, offset = 7.8125, width = 33.984375, ext_offset = 15
# successes = 1, resets = 0, offset = 8.984375, width = 33.984375, ext_offset = 21
# successes = 1, resets = 0, offset = 10.15625, width = 33.984375, ext_offset = 20
# successes = 1, resets = 0, offset = -37.5, width = 34.375, ext_offset = 12
# successes = 1, resets = 0, offset = -36.71875, width = 34.375, ext_offset = 18
# successes = 1, resets = 0, offset = 0.390625, width = 34.375, ext_offset = 19
# successes = 1, resets = 0, offset = 1.953125, width = 34.375, ext_offset = 15
# successes = 1, resets = 0, offset = 1.953125, width = 34.375, ext_offset = 20
# successes = 1, resets = 0, offset = 2.34375, width = 34.375, ext_offset = 21
# successes = 1, resets = 0, offset = 2.734375, width = 34.375, ext_offset = 17
# successes = 1, resets = 0, offset = 4.296875, width = 34.375, ext_offset = 17
# successes = 1, resets = 0, offset = 6.25, width = 34.375, ext_offset = 17
# successes = 1, resets = 0, offset = 9.375, width = 34.375, ext_offset = 16
# successes = 1, resets = 0, offset = -39.84375, width = 34.765625, ext_offset = 18
# successes = 1, resets = 0, offset = -39.453125, width = 34.765625, ext_offset = 18
# successes = 1, resets = 0, offset = -39.0625, width = 34.765625, ext_offset = 18
# successes = 1, resets = 0, offset = -38.28125, width = 34.765625, ext_offset = 18
# successes = 1, resets = 0, offset = -37.5, width = 34.765625, ext_offset = 18
# successes = 1, resets = 0, offset = -37.109375, width = 34.765625, ext_offset = 18
# successes = 1, resets = 0, offset = -36.71875, width = 34.765625, ext_offset = 18
# successes = 1, resets = 0, offset = -36.328125, width = 34.765625, ext_offset = 18
# successes = 1, resets = 0, offset = -35.9375, width = 34.765625, ext_offset = 18
# successes = 1, resets = 0, offset = -35.546875, width = 34.765625, ext_offset = 18
# successes = 1, resets = 0, offset = -35.15625, width = 34.765625, ext_offset = 18
# successes = 1, resets = 0, offset = -34.765625, width = 34.765625, ext_offset = 18
# successes = 1, resets = 0, offset = -34.375, width = 34.765625, ext_offset = 18
# successes = 1, resets = 0, offset = -33.984375, width = 34.765625, ext_offset = 18
# successes = 1, resets = 0, offset = -5.078125, width = 34.765625, ext_offset = 13
# successes = 1, resets = 0, offset = -2.734375, width = 34.765625, ext_offset = 15
# successes = 1, resets = 0, offset = -1.953125, width = 34.765625, ext_offset = 18
# successes = 1, resets = 0, offset = -1.953125, width = 34.765625, ext_offset = 30
# successes = 1, resets = 0, offset = -1.5625, width = 34.765625, ext_offset = 15
# successes = 1, resets = 0, offset = -0.78125, width = 34.765625, ext_offset = 17
# successes = 1, resets = 0, offset = 0.0, width = 34.765625, ext_offset = 17
# successes = 1, resets = 0, offset = 1.5625, width = 34.765625, ext_offset = 17
# successes = 1, resets = 0, offset = 1.953125, width = 34.765625, ext_offset = 21
# successes = 1, resets = 0, offset = 2.34375, width = 34.765625, ext_offset = 17
# successes = 1, resets = 0, offset = 8.984375, width = 34.765625, ext_offset = 17
# successes = 1, resets = 0, offset = -39.84375, width = 35.15625, ext_offset = 18
# successes = 1, resets = 0, offset = -39.453125, width = 35.15625, ext_offset = 18
# successes = 1, resets = 0, offset = -39.453125, width = 35.15625, ext_offset = 30
# successes = 1, resets = 0, offset = -39.0625, width = 35.15625, ext_offset = 18
# successes = 1, resets = 0, offset = -38.671875, width = 35.15625, ext_offset = 18
# successes = 1, resets = 0, offset = -38.28125, width = 35.15625, ext_offset = 18
# successes = 1, resets = 0, offset = -37.890625, width = 35.15625, ext_offset = 18
# successes = 1, resets = 0, offset = -37.5, width = 35.15625, ext_offset = 18
# successes = 1, resets = 0, offset = -37.109375, width = 35.15625, ext_offset = 18
# successes = 1, resets = 0, offset = -36.71875, width = 35.15625, ext_offset = 18
# successes = 1, resets = 0, offset = -36.328125, width = 35.15625, ext_offset = 18
# successes = 1, resets = 0, offset = -35.9375, width = 35.15625, ext_offset = 18
# successes = 1, resets = 0, offset = -35.546875, width = 35.15625, ext_offset = 18
# successes = 1, resets = 0, offset = -35.15625, width = 35.15625, ext_offset = 18
# successes = 1, resets = 0, offset = -34.765625, width = 35.15625, ext_offset = 18
# successes = 1, resets = 0, offset = -34.375, width = 35.15625, ext_offset = 18
# successes = 1, resets = 0, offset = -33.984375, width = 35.15625, ext_offset = 18
# successes = 1, resets = 0, offset = -33.59375, width = 35.15625, ext_offset = 18
# successes = 1, resets = 0, offset = -33.203125, width = 35.15625, ext_offset = 18
# successes = 1, resets = 0, offset = -14.0625, width = 35.15625, ext_offset = 16
# successes = 1, resets = 0, offset = -12.109375, width = 35.15625, ext_offset = 15
# successes = 1, resets = 0, offset = -10.15625, width = 35.15625, ext_offset = 19
# successes = 1, resets = 0, offset = -7.8125, width = 35.15625, ext_offset = 13
# successes = 1, resets = 0, offset = -7.8125, width = 35.15625, ext_offset = 16
# successes = 1, resets = 0, offset = -7.421875, width = 35.15625, ext_offset = 13
# successes = 1, resets = 0, offset = -5.859375, width = 35.15625, ext_offset = 30
# successes = 1, resets = 0, offset = -4.296875, width = 35.15625, ext_offset = 4
# successes = 1, resets = 0, offset = -3.515625, width = 35.15625, ext_offset = 17
# successes = 1, resets = 0, offset = -3.125, width = 35.15625, ext_offset = 16
# successes = 1, resets = 0, offset = -2.34375, width = 35.15625, ext_offset = 17
# successes = 1, resets = 0, offset = -39.84375, width = 35.546875, ext_offset = 15
# successes = 1, resets = 0, offset = -39.84375, width = 35.546875, ext_offset = 18
# successes = 1, resets = 0, offset = -39.453125, width = 35.546875, ext_offset = 13
# successes = 1, resets = 0, offset = -39.453125, width = 35.546875, ext_offset = 15
# successes = 1, resets = 0, offset = -39.453125, width = 35.546875, ext_offset = 18
# successes = 1, resets = 0, offset = -39.0625, width = 35.546875, ext_offset = 13
# successes = 1, resets = 0, offset = -39.0625, width = 35.546875, ext_offset = 15
# successes = 1, resets = 0, offset = -39.0625, width = 35.546875, ext_offset = 18
# successes = 1, resets = 0, offset = -39.0625, width = 35.546875, ext_offset = 30
# successes = 1, resets = 0, offset = -38.671875, width = 35.546875, ext_offset = 15
# successes = 1, resets = 0, offset = -38.671875, width = 35.546875, ext_offset = 18
# successes = 1, resets = 0, offset = -38.671875, width = 35.546875, ext_offset = 30
# successes = 1, resets = 0, offset = -38.28125, width = 35.546875, ext_offset = 18
# successes = 1, resets = 0, offset = -37.890625, width = 35.546875, ext_offset = 13
# successes = 1, resets = 0, offset = -37.890625, width = 35.546875, ext_offset = 18
# successes = 1, resets = 0, offset = -37.890625, width = 35.546875, ext_offset = 30
# successes = 1, resets = 0, offset = -37.5, width = 35.546875, ext_offset = 13
# successes = 1, resets = 0, offset = -37.5, width = 35.546875, ext_offset = 18
# successes = 1, resets = 0, offset = -37.109375, width = 35.546875, ext_offset = 18
# successes = 1, resets = 0, offset = -37.109375, width = 35.546875, ext_offset = 30
# successes = 1, resets = 0, offset = -36.71875, width = 35.546875, ext_offset = 13
# successes = 1, resets = 0, offset = -36.71875, width = 35.546875, ext_offset = 18
# successes = 1, resets = 0, offset = -36.328125, width = 35.546875, ext_offset = 12
# successes = 1, resets = 0, offset = -36.328125, width = 35.546875, ext_offset = 13
# successes = 1, resets = 0, offset = -36.328125, width = 35.546875, ext_offset = 15
# successes = 1, resets = 0, offset = -36.328125, width = 35.546875, ext_offset = 18
# successes = 1, resets = 0, offset = -35.9375, width = 35.546875, ext_offset = 15
# successes = 1, resets = 0, offset = -35.9375, width = 35.546875, ext_offset = 18
# successes = 1, resets = 0, offset = -35.546875, width = 35.546875, ext_offset = 15
# successes = 1, resets = 0, offset = -35.546875, width = 35.546875, ext_offset = 18
# successes = 1, resets = 0, offset = -35.546875, width = 35.546875, ext_offset = 30
# successes = 1, resets = 0, offset = -35.15625, width = 35.546875, ext_offset = 18
# successes = 1, resets = 0, offset = -34.765625, width = 35.546875, ext_offset = 13
# successes = 1, resets = 0, offset = -34.765625, width = 35.546875, ext_offset = 15
# successes = 1, resets = 0, offset = -34.765625, width = 35.546875, ext_offset = 18
# successes = 1, resets = 0, offset = -34.765625, width = 35.546875, ext_offset = 30
# successes = 1, resets = 0, offset = -34.375, width = 35.546875, ext_offset = 15
# successes = 1, resets = 0, offset = -34.375, width = 35.546875, ext_offset = 18
# successes = 1, resets = 0, offset = -33.984375, width = 35.546875, ext_offset = 13
# successes = 1, resets = 0, offset = -33.984375, width = 35.546875, ext_offset = 15
# successes = 1, resets = 0, offset = -33.984375, width = 35.546875, ext_offset = 18
# successes = 1, resets = 0, offset = -33.59375, width = 35.546875, ext_offset = 15
# successes = 1, resets = 0, offset = -33.59375, width = 35.546875, ext_offset = 18
# successes = 1, resets = 0, offset = -16.40625, width = 35.546875, ext_offset = 15
# successes = 1, resets = 0, offset = -16.015625, width = 35.546875, ext_offset = 15
# successes = 1, resets = 0, offset = -16.015625, width = 35.546875, ext_offset = 16
# successes = 1, resets = 0, offset = -16.015625, width = 35.546875, ext_offset = 17
# successes = 1, resets = 0, offset = -15.625, width = 35.546875, ext_offset = 15
# successes = 1, resets = 0, offset = -15.234375, width = 35.546875, ext_offset = 15
# successes = 1, resets = 0, offset = -15.234375, width = 35.546875, ext_offset = 16
# successes = 1, resets = 0, offset = -14.84375, width = 35.546875, ext_offset = 15
# successes = 1, resets = 0, offset = -14.84375, width = 35.546875, ext_offset = 16
# successes = 1, resets = 0, offset = -14.0625, width = 35.546875, ext_offset = 17
# successes = 1, resets = 0, offset = -13.671875, width = 35.546875, ext_offset = 16
# successes = 1, resets = 0, offset = -13.28125, width = 35.546875, ext_offset = 16
# successes = 1, resets = 0, offset = -12.890625, width = 35.546875, ext_offset = 16
# successes = 1, resets = 0, offset = -12.5, width = 35.546875, ext_offset = 15
# successes = 1, resets = 0, offset = -12.109375, width = 35.546875, ext_offset = 15
# successes = 1, resets = 0, offset = -12.109375, width = 35.546875, ext_offset = 17
# successes = 1, resets = 0, offset = -11.71875, width = 35.546875, ext_offset = 15
# successes = 1, resets = 0, offset = -11.71875, width = 35.546875, ext_offset = 16
# successes = 1, resets = 0, offset = -11.328125, width = 35.546875, ext_offset = 16
# successes = 1, resets = 0, offset = -10.9375, width = 35.546875, ext_offset = 16
# successes = 1, resets = 0, offset = -10.15625, width = 35.546875, ext_offset = 15
# successes = 1, resets = 0, offset = -10.15625, width = 35.546875, ext_offset = 18
# successes = 1, resets = 0, offset = -9.375, width = 35.546875, ext_offset = 16
# successes = 1, resets = 0, offset = -8.984375, width = 35.546875, ext_offset = 18
# successes = 1, resets = 0, offset = -8.59375, width = 35.546875, ext_offset = 18
# successes = 1, resets = 0, offset = -7.421875, width = 35.546875, ext_offset = 4
# successes = 1, resets = 0, offset = -7.03125, width = 35.546875, ext_offset = 15
# successes = 1, resets = 0, offset = -7.03125, width = 35.546875, ext_offset = 18
# successes = 1, resets = 0, offset = -5.46875, width = 35.546875, ext_offset = 17
# successes = 1, resets = 0, offset = -5.078125, width = 35.546875, ext_offset = 17
# successes = 1, resets = 0, offset = -4.296875, width = 35.546875, ext_offset = 16
# successes = 1, resets = 0, offset = -4.296875, width = 35.546875, ext_offset = 17
# successes = 1, resets = 0, offset = -39.84375, width = 35.9375, ext_offset = 13
# successes = 1, resets = 0, offset = -39.84375, width = 35.9375, ext_offset = 15
# successes = 1, resets = 0, offset = -39.453125, width = 35.9375, ext_offset = 15
# successes = 1, resets = 0, offset = -39.453125, width = 35.9375, ext_offset = 18
# successes = 1, resets = 0, offset = -39.0625, width = 35.9375, ext_offset = 13
# successes = 1, resets = 0, offset = -39.0625, width = 35.9375, ext_offset = 15
# successes = 1, resets = 0, offset = -39.0625, width = 35.9375, ext_offset = 18
# successes = 1, resets = 0, offset = -38.671875, width = 35.9375, ext_offset = 13
# successes = 1, resets = 0, offset = -38.671875, width = 35.9375, ext_offset = 15
# successes = 1, resets = 0, offset = -38.28125, width = 35.9375, ext_offset = 15
# successes = 1, resets = 0, offset = -38.28125, width = 35.9375, ext_offset = 30
# successes = 1, resets = 0, offset = -37.890625, width = 35.9375, ext_offset = 15
# successes = 1, resets = 0, offset = -37.890625, width = 35.9375, ext_offset = 18
# successes = 1, resets = 0, offset = -37.890625, width = 35.9375, ext_offset = 30
# successes = 1, resets = 0, offset = -37.5, width = 35.9375, ext_offset = 13
# successes = 1, resets = 0, offset = -37.5, width = 35.9375, ext_offset = 15
# successes = 1, resets = 0, offset = -37.5, width = 35.9375, ext_offset = 18
# successes = 1, resets = 0, offset = -37.5, width = 35.9375, ext_offset = 30
# successes = 1, resets = 0, offset = -37.109375, width = 35.9375, ext_offset = 13
# successes = 1, resets = 0, offset = -37.109375, width = 35.9375, ext_offset = 15
# successes = 1, resets = 0, offset = -37.109375, width = 35.9375, ext_offset = 18
# successes = 1, resets = 0, offset = -36.71875, width = 35.9375, ext_offset = 13
# successes = 1, resets = 0, offset = -36.71875, width = 35.9375, ext_offset = 15
# successes = 1, resets = 0, offset = -36.71875, width = 35.9375, ext_offset = 30
# successes = 1, resets = 0, offset = -36.328125, width = 35.9375, ext_offset = 15
# successes = 1, resets = 0, offset = -36.328125, width = 35.9375, ext_offset = 18
# successes = 1, resets = 0, offset = -36.328125, width = 35.9375, ext_offset = 30
# successes = 1, resets = 0, offset = -35.9375, width = 35.9375, ext_offset = 13
# successes = 1, resets = 0, offset = -35.9375, width = 35.9375, ext_offset = 15
# successes = 1, resets = 0, offset = -35.9375, width = 35.9375, ext_offset = 18
# successes = 1, resets = 0, offset = -35.9375, width = 35.9375, ext_offset = 30
# successes = 1, resets = 0, offset = -35.546875, width = 35.9375, ext_offset = 13
# successes = 1, resets = 0, offset = -35.546875, width = 35.9375, ext_offset = 15
# successes = 1, resets = 0, offset = -35.546875, width = 35.9375, ext_offset = 30
# successes = 1, resets = 0, offset = -35.15625, width = 35.9375, ext_offset = 13
# successes = 1, resets = 0, offset = -35.15625, width = 35.9375, ext_offset = 15
# successes = 1, resets = 0, offset = -35.15625, width = 35.9375, ext_offset = 30
# successes = 1, resets = 0, offset = -34.765625, width = 35.9375, ext_offset = 13
# successes = 1, resets = 0, offset = -34.765625, width = 35.9375, ext_offset = 15
# successes = 1, resets = 0, offset = -34.765625, width = 35.9375, ext_offset = 18
# successes = 1, resets = 0, offset = -34.375, width = 35.9375, ext_offset = 13
# successes = 1, resets = 0, offset = -34.375, width = 35.9375, ext_offset = 15
# successes = 1, resets = 0, offset = -34.375, width = 35.9375, ext_offset = 18
# successes = 1, resets = 0, offset = -34.375, width = 35.9375, ext_offset = 30
# successes = 1, resets = 0, offset = -33.984375, width = 35.9375, ext_offset = 15
# successes = 1, resets = 0, offset = -33.984375, width = 35.9375, ext_offset = 30
# successes = 1, resets = 0, offset = -33.59375, width = 35.9375, ext_offset = 13
# successes = 1, resets = 0, offset = -33.59375, width = 35.9375, ext_offset = 15
# successes = 1, resets = 0, offset = -33.59375, width = 35.9375, ext_offset = 18
# successes = 1, resets = 0, offset = -33.59375, width = 35.9375, ext_offset = 30
# successes = 1, resets = 0, offset = -17.1875, width = 35.9375, ext_offset = 18
# successes = 1, resets = 0, offset = -16.796875, width = 35.9375, ext_offset = 17
# successes = 1, resets = 0, offset = -16.40625, width = 35.9375, ext_offset = 17
# successes = 1, resets = 0, offset = -16.015625, width = 35.9375, ext_offset = 15
# successes = 1, resets = 0, offset = -16.015625, width = 35.9375, ext_offset = 16
# successes = 1, resets = 0, offset = -16.015625, width = 35.9375, ext_offset = 17
# successes = 1, resets = 0, offset = -15.625, width = 35.9375, ext_offset = 18
# successes = 1, resets = 0, offset = -15.234375, width = 35.9375, ext_offset = 15
# successes = 1, resets = 0, offset = -15.234375, width = 35.9375, ext_offset = 16
# successes = 1, resets = 0, offset = -14.453125, width = 35.9375, ext_offset = 18
# successes = 1, resets = 0, offset = -13.671875, width = 35.9375, ext_offset = 18
# successes = 1, resets = 0, offset = -12.109375, width = 35.9375, ext_offset = 17
# successes = 1, resets = 0, offset = -11.328125, width = 35.9375, ext_offset = 17
# successes = 1, resets = 0, offset = -10.9375, width = 35.9375, ext_offset = 17
# successes = 1, resets = 0, offset = -10.546875, width = 35.9375, ext_offset = 17
# successes = 1, resets = 0, offset = -10.546875, width = 35.9375, ext_offset = 18
# successes = 1, resets = 0, offset = -10.15625, width = 35.9375, ext_offset = 17
# successes = 1, resets = 0, offset = -10.15625, width = 35.9375, ext_offset = 18
# successes = 1, resets = 0, offset = -9.765625, width = 35.9375, ext_offset = 17
# successes = 1, resets = 0, offset = -8.984375, width = 35.9375, ext_offset = 17
# successes = 1, resets = 0, offset = -8.59375, width = 35.9375, ext_offset = 17
# successes = 1, resets = 0, offset = -7.03125, width = 35.9375, ext_offset = 17
# successes = 1, resets = 0, offset = -5.859375, width = 35.9375, ext_offset = 17
# successes = 1, resets = 0, offset = -5.46875, width = 35.9375, ext_offset = 17
# successes = 1, resets = 0, offset = -3.90625, width = 35.9375, ext_offset = 19
# Done glitching

# %% [markdown]
# With that done, let's print our results. You'll likely want to ignore the "tries" and "ext_offset" parameters:

# %%
results = gc.calc(ignore_params=["tries", "ext_offset"], sort="success_rate")
results
# Out:
# [((35.99999999999999, -33.60000000000002),
#   {'total': 27,
#    'success': 4,
#    'success_rate': 0.14814814814814814,
#    'reset': 3,
#    'reset_rate': 0.1111111111111111,
#    'normal': 20,
#    'normal_rate': 0.7407407407407407}),
#  ((35.99999999999999, -34.40000000000002),
#   {'total': 27,
#    'success': 4,
#    'success_rate': 0.14814814814814814,
#    'reset': 3,
#    'reset_rate': 0.1111111111111111,
#    'normal': 20,
#    'normal_rate': 0.7407407407407407}),
#  ((35.99999999999999, -36.000000000000014),
#   {'total': 27,
#    'success': 4,
#    'success_rate': 0.14814814814814814,
#    'reset': 3,
#    'reset_rate': 0.1111111111111111,
#    'normal': 20,
#    'normal_rate': 0.7407407407407407}),
#  ((35.99999999999999, -37.60000000000001),
#   {'total': 27,
#    'success': 4,
#    'success_rate': 0.14814814814814814,
#    'reset': 3,
#    'reset_rate': 0.1111111111111111,
#    'normal': 20,
#    'normal_rate': 0.7407407407407407}),
#  ((35.599999999999994, -34.80000000000002),
#   {'total': 27,
#    'success': 4,
#    'success_rate': 0.14814814814814814,
#    'reset': 3,
#    'reset_rate': 0.1111111111111111,
#    'normal': 20,
#    'normal_rate': 0.7407407407407407}),
#  ((35.599999999999994, -36.40000000000001),
#   {'total': 27,
#    'success': 4,
#    'success_rate': 0.14814814814814814,
#    'reset': 2,
#    'reset_rate': 0.07407407407407407,
#    'normal': 21,
#    'normal_rate': 0.7777777777777778}),
#  ((35.599999999999994, -39.2),
#   {'total': 27,
#    'success': 4,
#    'success_rate': 0.14814814814814814,
#    'reset': 1,
#    'reset_rate': 0.037037037037037035,
#    'normal': 22,
#    'normal_rate': 0.8148148148148148}),
#  ((35.99999999999999, -16.000000000000085),
#   {'total': 27,
#    'success': 3,
#    'success_rate': 0.1111111111111111,
#    'reset': 5,
#    'reset_rate': 0.18518518518518517,
#    'normal': 19,
#    'normal_rate': 0.7037037037037037}),
#  ((35.99999999999999, -34.80000000000002),
#   {'total': 27,
#    'success': 3,
#    'success_rate': 0.1111111111111111,
#    'reset': 4,
#    'reset_rate': 0.14814814814814814,
#    'normal': 20,
#    'normal_rate': 0.7407407407407407}),
#  ((35.99999999999999, -35.20000000000002),
#   {'total': 27,
#    'success': 3,
#    'success_rate': 0.1111111111111111,
#    'reset': 4,
#    'reset_rate': 0.14814814814814814,
#    'normal': 20,
#    'normal_rate': 0.7407407407407407}),
#  ((35.99999999999999, -35.600000000000016),
#   {'total': 27,
#    'success': 3,
#    'success_rate': 0.1111111111111111,
#    'reset': 3,
#    'reset_rate': 0.1111111111111111,
#    'normal': 21,
#    'normal_rate': 0.7777777777777778}),
#  ((35.99999999999999, -36.40000000000001),
#   {'total': 27,
#    'success': 3,
#    'success_rate': 0.1111111111111111,
#    'reset': 4,
#    'reset_rate': 0.14814814814814814,
#    'normal': 20,
#    'normal_rate': 0.7407407407407407}),
#  ((35.99999999999999, -36.80000000000001),
#   {'total': 27,
#    'success': 3,
#    'success_rate': 0.1111111111111111,
#    'reset': 4,
#    'reset_rate': 0.14814814814814814,
#    'normal': 20,
#    'normal_rate': 0.7407407407407407}),
#  ((35.99999999999999, -37.20000000000001),
#   {'total': 27,
#    'success': 3,
#    'success_rate': 0.1111111111111111,
#    'reset': 5,
#    'reset_rate': 0.18518518518518517,
#    'normal': 19,
#    'normal_rate': 0.7037037037037037}),
#  ((35.99999999999999, -38.00000000000001),
#   {'total': 27,
#    'success': 3,
#    'success_rate': 0.1111111111111111,
#    'reset': 5,
#    'reset_rate': 0.18518518518518517,
#    'normal': 19,
#    'normal_rate': 0.7037037037037037}),
#  ((35.99999999999999, -39.2),
#   {'total': 27,
#    'success': 3,
#    'success_rate': 0.1111111111111111,
#    'reset': 5,
#    'reset_rate': 0.18518518518518517,
#    'normal': 19,
#    'normal_rate': 0.7037037037037037}),
#  ((35.599999999999994, -16.000000000000085),
#   {'total': 27,
#    'success': 3,
#    'success_rate': 0.1111111111111111,
#    'reset': 3,
#    'reset_rate': 0.1111111111111111,
#    'normal': 21,
#    'normal_rate': 0.7777777777777778}),
#  ((35.599999999999994, -34.00000000000002),
#   {'total': 27,
#    'success': 3,
#    'success_rate': 0.1111111111111111,
#    'reset': 1,
#    'reset_rate': 0.037037037037037035,
#    'normal': 23,
#    'normal_rate': 0.8518518518518519}),
#  ((35.599999999999994, -35.600000000000016),
#   {'total': 27,
#    'success': 3,
#    'success_rate': 0.1111111111111111,
#    'reset': 1,
#    'reset_rate': 0.037037037037037035,
#    'normal': 23,
#    'normal_rate': 0.8518518518518519}),
#  ((35.599999999999994, -38.00000000000001),
#   {'total': 27,
#    'success': 3,
#    'success_rate': 0.1111111111111111,
#    'reset': 1,
#    'reset_rate': 0.037037037037037035,
#    'normal': 23,
#    'normal_rate': 0.8518518518518519}),
#  ((35.599999999999994, -38.800000000000004),
#   {'total': 27,
#    'success': 3,
#    'success_rate': 0.1111111111111111,
#    'reset': 2,
#    'reset_rate': 0.07407407407407407,
#    'normal': 22,
#    'normal_rate': 0.8148148148148148}),
#  ((35.599999999999994, -39.6),
#   {'total': 27,
#    'success': 3,
#    'success_rate': 0.1111111111111111,
#    'reset': 1,
#    'reset_rate': 0.037037037037037035,
#    'normal': 23,
#    'normal_rate': 0.8518518518518519}),
#  ((35.99999999999999, -10.00000000000008),
#   {'total': 27,
#    'success': 2,
#    'success_rate': 0.07407407407407407,
#    'reset': 9,
#    'reset_rate': 0.3333333333333333,
#    'normal': 16,
#    'normal_rate': 0.5925925925925926}),
#  ((35.99999999999999, -10.40000000000008),
#   {'total': 27,
#    'success': 2,
#    'success_rate': 0.07407407407407407,
#    'reset': 10,
#    'reset_rate': 0.37037037037037035,
#    'normal': 15,
#    'normal_rate': 0.5555555555555556}),
#  ((35.99999999999999, -15.200000000000085),
#   {'total': 27,
#    'success': 2,
#    'success_rate': 0.07407407407407407,
#    'reset': 7,
#    'reset_rate': 0.25925925925925924,
#    'normal': 18,
#    'normal_rate': 0.6666666666666666}),
#  ((35.99999999999999, -34.00000000000002),
#   {'total': 27,
#    'success': 2,
#    'success_rate': 0.07407407407407407,
#    'reset': 3,
#    'reset_rate': 0.1111111111111111,
#    'normal': 22,
#    'normal_rate': 0.8148148148148148}),
#  ((35.99999999999999, -38.400000000000006),
#   {'total': 27,
#    'success': 2,
#    'success_rate': 0.07407407407407407,
#    'reset': 4,
#    'reset_rate': 0.14814814814814814,
#    'normal': 21,
#    'normal_rate': 0.7777777777777778}),
#  ((35.99999999999999, -38.800000000000004),
#   {'total': 27,
#    'success': 2,
#    'success_rate': 0.07407407407407407,
#    'reset': 6,
#    'reset_rate': 0.2222222222222222,
#    'normal': 19,
#    'normal_rate': 0.7037037037037037}),
#  ((35.99999999999999, -39.6),
#   {'total': 27,
#    'success': 2,
#    'success_rate': 0.07407407407407407,
#    'reset': 6,
#    'reset_rate': 0.2222222222222222,
#    'normal': 19,
#    'normal_rate': 0.7037037037037037}),
#  ((35.99999999999999, -40),
#   {'total': 27,
#    'success': 2,
#    'success_rate': 0.07407407407407407,
#    'reset': 8,
#    'reset_rate': 0.2962962962962963,
#    'normal': 17,
#    'normal_rate': 0.6296296296296297}),
#  ((35.599999999999994, -4.400000000000075),
#   {'total': 27,
#    'success': 2,
#    'success_rate': 0.07407407407407407,
#    'reset': 11,
#    'reset_rate': 0.4074074074074074,
#    'normal': 14,
#    'normal_rate': 0.5185185185185185}),
#  ((35.599999999999994, -7.2000000000000774),
#   {'total': 27,
#    'success': 2,
#    'success_rate': 0.07407407407407407,
#    'reset': 7,
#    'reset_rate': 0.25925925925925924,
#    'normal': 18,
#    'normal_rate': 0.6666666666666666}),
#  ((35.599999999999994, -10.00000000000008),
#   {'total': 27,
#    'success': 2,
#    'success_rate': 0.07407407407407407,
#    'reset': 4,
#    'reset_rate': 0.14814814814814814,
#    'normal': 21,
#    'normal_rate': 0.7777777777777778}),
#  ((35.599999999999994, -11.600000000000081),
#   {'total': 27,
#    'success': 2,
#    'success_rate': 0.07407407407407407,
#    'reset': 6,
#    'reset_rate': 0.2222222222222222,
#    'normal': 19,
#    'normal_rate': 0.7037037037037037}),
#  ((35.599999999999994, -12.000000000000082),
#   {'total': 27,
#    'success': 2,
#    'success_rate': 0.07407407407407407,
#    'reset': 3,
#    'reset_rate': 0.1111111111111111,
#    'normal': 22,
#    'normal_rate': 0.8148148148148148}),
#  ((35.599999999999994, -14.800000000000084),
#   {'total': 27,
#    'success': 2,
#    'success_rate': 0.07407407407407407,
#    'reset': 5,
#    'reset_rate': 0.18518518518518517,
#    'normal': 20,
#    'normal_rate': 0.7407407407407407}),
#  ((35.599999999999994, -15.200000000000085),
#   {'total': 27,
#    'success': 2,
#    'success_rate': 0.07407407407407407,
#    'reset': 3,
#    'reset_rate': 0.1111111111111111,
#    'normal': 22,
#    'normal_rate': 0.8148148148148148}),
#  ((35.599999999999994, -33.60000000000002),
#   {'total': 27,
#    'success': 2,
#    'success_rate': 0.07407407407407407,
#    'reset': 1,
#    'reset_rate': 0.037037037037037035,
#    'normal': 24,
#    'normal_rate': 0.8888888888888888}),
#  ((35.599999999999994, -34.40000000000002),
#   {'total': 27,
#    'success': 2,
#    'success_rate': 0.07407407407407407,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 25,
#    'normal_rate': 0.9259259259259259}),
#  ((35.599999999999994, -36.000000000000014),
#   {'total': 27,
#    'success': 2,
#    'success_rate': 0.07407407407407407,
#    'reset': 1,
#    'reset_rate': 0.037037037037037035,
#    'normal': 24,
#    'normal_rate': 0.8888888888888888}),
#  ((35.599999999999994, -36.80000000000001),
#   {'total': 27,
#    'success': 2,
#    'success_rate': 0.07407407407407407,
#    'reset': 3,
#    'reset_rate': 0.1111111111111111,
#    'normal': 22,
#    'normal_rate': 0.8148148148148148}),
#  ((35.599999999999994, -37.20000000000001),
#   {'total': 27,
#    'success': 2,
#    'success_rate': 0.07407407407407407,
#    'reset': 2,
#    'reset_rate': 0.07407407407407407,
#    'normal': 23,
#    'normal_rate': 0.8518518518518519}),
#  ((35.599999999999994, -37.60000000000001),
#   {'total': 27,
#    'success': 2,
#    'success_rate': 0.07407407407407407,
#    'reset': 1,
#    'reset_rate': 0.037037037037037035,
#    'normal': 24,
#    'normal_rate': 0.8888888888888888}),
#  ((35.599999999999994, -40),
#   {'total': 27,
#    'success': 2,
#    'success_rate': 0.07407407407407407,
#    'reset': 3,
#    'reset_rate': 0.1111111111111111,
#    'normal': 22,
#    'normal_rate': 0.8148148148148148}),
#  ((35.199999999999996, -8.000000000000078),
#   {'total': 27,
#    'success': 2,
#    'success_rate': 0.07407407407407407,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 25,
#    'normal_rate': 0.9259259259259259}),
#  ((35.199999999999996, -39.6),
#   {'total': 27,
#    'success': 2,
#    'success_rate': 0.07407407407407407,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 25,
#    'normal_rate': 0.9259259259259259}),
#  ((34.8, -2.000000000000075),
#   {'total': 27,
#    'success': 2,
#    'success_rate': 0.07407407407407407,
#    'reset': 5,
#    'reset_rate': 0.18518518518518517,
#    'normal': 20,
#    'normal_rate': 0.7407407407407407}),
#  ((34.4, 1.999999999999925),
#   {'total': 27,
#    'success': 2,
#    'success_rate': 0.07407407407407407,
#    'reset': 8,
#    'reset_rate': 0.2962962962962963,
#    'normal': 17,
#    'normal_rate': 0.6296296296296297}),
#  ((34, 1.999999999999925),
#   {'total': 27,
#    'success': 2,
#    'success_rate': 0.07407407407407407,
#    'reset': 2,
#    'reset_rate': 0.07407407407407407,
#    'normal': 23,
#    'normal_rate': 0.8518518518518519}),
#  ((35.99999999999999, -4.000000000000075),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 14,
#    'reset_rate': 0.5185185185185185,
#    'normal': 12,
#    'normal_rate': 0.4444444444444444}),
#  ((35.99999999999999, -5.600000000000076),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 13,
#    'reset_rate': 0.48148148148148145,
#    'normal': 13,
#    'normal_rate': 0.48148148148148145}),
#  ((35.99999999999999, -6.000000000000076),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 12,
#    'reset_rate': 0.4444444444444444,
#    'normal': 14,
#    'normal_rate': 0.5185185185185185}),
#  ((35.99999999999999, -7.2000000000000774),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 12,
#    'reset_rate': 0.4444444444444444,
#    'normal': 14,
#    'normal_rate': 0.5185185185185185}),
#  ((35.99999999999999, -8.400000000000079),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 13,
#    'reset_rate': 0.48148148148148145,
#    'normal': 13,
#    'normal_rate': 0.48148148148148145}),
#  ((35.99999999999999, -8.800000000000079),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 12,
#    'reset_rate': 0.4444444444444444,
#    'normal': 14,
#    'normal_rate': 0.5185185185185185}),
#  ((35.99999999999999, -9.60000000000008),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 10,
#    'reset_rate': 0.37037037037037035,
#    'normal': 16,
#    'normal_rate': 0.5925925925925926}),
#  ((35.99999999999999, -10.80000000000008),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 10,
#    'reset_rate': 0.37037037037037035,
#    'normal': 16,
#    'normal_rate': 0.5925925925925926}),
#  ((35.99999999999999, -11.200000000000081),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 11,
#    'reset_rate': 0.4074074074074074,
#    'normal': 15,
#    'normal_rate': 0.5555555555555556}),
#  ((35.99999999999999, -12.000000000000082),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 10,
#    'reset_rate': 0.37037037037037035,
#    'normal': 16,
#    'normal_rate': 0.5925925925925926}),
#  ((35.99999999999999, -13.600000000000083),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 11,
#    'reset_rate': 0.4074074074074074,
#    'normal': 15,
#    'normal_rate': 0.5555555555555556}),
#  ((35.99999999999999, -14.400000000000084),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 10,
#    'reset_rate': 0.37037037037037035,
#    'normal': 16,
#    'normal_rate': 0.5925925925925926}),
#  ((35.99999999999999, -15.600000000000085),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 7,
#    'reset_rate': 0.25925925925925924,
#    'normal': 19,
#    'normal_rate': 0.7037037037037037}),
#  ((35.99999999999999, -16.400000000000084),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 4,
#    'reset_rate': 0.14814814814814814,
#    'normal': 22,
#    'normal_rate': 0.8148148148148148}),
#  ((35.99999999999999, -16.800000000000082),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 2,
#    'reset_rate': 0.07407407407407407,
#    'normal': 24,
#    'normal_rate': 0.8888888888888888}),
#  ((35.99999999999999, -17.20000000000008),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 1,
#    'reset_rate': 0.037037037037037035,
#    'normal': 25,
#    'normal_rate': 0.9259259259259259}),
#  ((35.599999999999994, -5.200000000000076),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 10,
#    'reset_rate': 0.37037037037037035,
#    'normal': 16,
#    'normal_rate': 0.5925925925925926}),
#  ((35.599999999999994, -5.600000000000076),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 9,
#    'reset_rate': 0.3333333333333333,
#    'normal': 17,
#    'normal_rate': 0.6296296296296297}),
#  ((35.599999999999994, -8.000000000000078),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 4,
#    'reset_rate': 0.14814814814814814,
#    'normal': 22,
#    'normal_rate': 0.8148148148148148}),
#  ((35.599999999999994, -8.400000000000079),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 3,
#    'reset_rate': 0.1111111111111111,
#    'normal': 23,
#    'normal_rate': 0.8518518518518519}),
#  ((35.599999999999994, -8.800000000000079),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 4,
#    'reset_rate': 0.14814814814814814,
#    'normal': 22,
#    'normal_rate': 0.8148148148148148}),
#  ((35.599999999999994, -9.20000000000008),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 3,
#    'reset_rate': 0.1111111111111111,
#    'normal': 23,
#    'normal_rate': 0.8518518518518519}),
#  ((35.599999999999994, -10.80000000000008),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 3,
#    'reset_rate': 0.1111111111111111,
#    'normal': 23,
#    'normal_rate': 0.8518518518518519}),
#  ((35.599999999999994, -11.200000000000081),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 2,
#    'reset_rate': 0.07407407407407407,
#    'normal': 24,
#    'normal_rate': 0.8888888888888888}),
#  ((35.599999999999994, -12.400000000000082),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 5,
#    'reset_rate': 0.18518518518518517,
#    'normal': 21,
#    'normal_rate': 0.7777777777777778}),
#  ((35.599999999999994, -12.800000000000082),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 4,
#    'reset_rate': 0.14814814814814814,
#    'normal': 22,
#    'normal_rate': 0.8148148148148148}),
#  ((35.599999999999994, -13.200000000000083),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 3,
#    'reset_rate': 0.1111111111111111,
#    'normal': 23,
#    'normal_rate': 0.8518518518518519}),
#  ((35.599999999999994, -13.600000000000083),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 6,
#    'reset_rate': 0.2222222222222222,
#    'normal': 20,
#    'normal_rate': 0.7407407407407407}),
#  ((35.599999999999994, -14.000000000000083),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 6,
#    'reset_rate': 0.2222222222222222,
#    'normal': 20,
#    'normal_rate': 0.7407407407407407}),
#  ((35.599999999999994, -15.600000000000085),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 4,
#    'reset_rate': 0.14814814814814814,
#    'normal': 22,
#    'normal_rate': 0.8148148148148148}),
#  ((35.599999999999994, -16.400000000000084),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 3,
#    'reset_rate': 0.1111111111111111,
#    'normal': 23,
#    'normal_rate': 0.8518518518518519}),
#  ((35.599999999999994, -35.20000000000002),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 1,
#    'reset_rate': 0.037037037037037035,
#    'normal': 25,
#    'normal_rate': 0.9259259259259259}),
#  ((35.599999999999994, -38.400000000000006),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 2,
#    'reset_rate': 0.07407407407407407,
#    'normal': 24,
#    'normal_rate': 0.8888888888888888}),
#  ((35.199999999999996, -2.400000000000075),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 10,
#    'reset_rate': 0.37037037037037035,
#    'normal': 16,
#    'normal_rate': 0.5925925925925926}),
#  ((35.199999999999996, -3.200000000000075),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 6,
#    'reset_rate': 0.2222222222222222,
#    'normal': 20,
#    'normal_rate': 0.7407407407407407}),
#  ((35.199999999999996, -3.6000000000000747),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 9,
#    'reset_rate': 0.3333333333333333,
#    'normal': 17,
#    'normal_rate': 0.6296296296296297}),
#  ((35.199999999999996, -4.800000000000075),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 6,
#    'reset_rate': 0.2222222222222222,
#    'normal': 20,
#    'normal_rate': 0.7407407407407407}),
#  ((35.199999999999996, -6.000000000000076),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 1,
#    'reset_rate': 0.037037037037037035,
#    'normal': 25,
#    'normal_rate': 0.9259259259259259}),
#  ((35.199999999999996, -7.600000000000078),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 1,
#    'reset_rate': 0.037037037037037035,
#    'normal': 25,
#    'normal_rate': 0.9259259259259259}),
#  ((35.199999999999996, -10.00000000000008),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 1,
#    'reset_rate': 0.037037037037037035,
#    'normal': 25,
#    'normal_rate': 0.9259259259259259}),
#  ((35.199999999999996, -12.000000000000082),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 26,
#    'normal_rate': 0.9629629629629629}),
#  ((35.199999999999996, -14.000000000000083),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 2,
#    'reset_rate': 0.07407407407407407,
#    'normal': 24,
#    'normal_rate': 0.8888888888888888}),
#  ((35.199999999999996, -33.200000000000024),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 26,
#    'normal_rate': 0.9629629629629629}),
#  ((35.199999999999996, -33.60000000000002),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 26,
#    'normal_rate': 0.9629629629629629}),
#  ((35.199999999999996, -34.00000000000002),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 26,
#    'normal_rate': 0.9629629629629629}),
#  ((35.199999999999996, -34.40000000000002),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 1,
#    'reset_rate': 0.037037037037037035,
#    'normal': 25,
#    'normal_rate': 0.9259259259259259}),
#  ((35.199999999999996, -34.80000000000002),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 26,
#    'normal_rate': 0.9629629629629629}),
#  ((35.199999999999996, -35.20000000000002),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 26,
#    'normal_rate': 0.9629629629629629}),
#  ((35.199999999999996, -35.600000000000016),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 26,
#    'normal_rate': 0.9629629629629629}),
#  ((35.199999999999996, -36.000000000000014),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 26,
#    'normal_rate': 0.9629629629629629}),
#  ((35.199999999999996, -36.40000000000001),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 26,
#    'normal_rate': 0.9629629629629629}),
#  ((35.199999999999996, -36.80000000000001),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 26,
#    'normal_rate': 0.9629629629629629}),
#  ((35.199999999999996, -37.20000000000001),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 26,
#    'normal_rate': 0.9629629629629629}),
#  ((35.199999999999996, -37.60000000000001),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 26,
#    'normal_rate': 0.9629629629629629}),
#  ((35.199999999999996, -38.00000000000001),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 26,
#    'normal_rate': 0.9629629629629629}),
#  ((35.199999999999996, -38.400000000000006),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 26,
#    'normal_rate': 0.9629629629629629}),
#  ((35.199999999999996, -38.800000000000004),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 26,
#    'normal_rate': 0.9629629629629629}),
#  ((35.199999999999996, -39.2),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 26,
#    'normal_rate': 0.9629629629629629}),
#  ((35.199999999999996, -40),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 26,
#    'normal_rate': 0.9629629629629629}),
#  ((34.8, 8.799999999999928),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 12,
#    'reset_rate': 0.4444444444444444,
#    'normal': 14,
#    'normal_rate': 0.5185185185185185}),
#  ((34.8, 2.399999999999925),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 12,
#    'reset_rate': 0.4444444444444444,
#    'normal': 14,
#    'normal_rate': 0.5185185185185185}),
#  ((34.8, 1.999999999999925),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 12,
#    'reset_rate': 0.4444444444444444,
#    'normal': 14,
#    'normal_rate': 0.5185185185185185}),
#  ((34.8, 1.599999999999925),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 13,
#    'reset_rate': 0.48148148148148145,
#    'normal': 13,
#    'normal_rate': 0.48148148148148145}),
#  ((34.8, -7.51620987671231e-14),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 12,
#    'reset_rate': 0.4444444444444444,
#    'normal': 14,
#    'normal_rate': 0.5185185185185185}),
#  ((34.8, -0.8000000000000752),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 11,
#    'reset_rate': 0.4074074074074074,
#    'normal': 15,
#    'normal_rate': 0.5555555555555556}),
#  ((34.8, -1.6000000000000751),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 6,
#    'reset_rate': 0.2222222222222222,
#    'normal': 20,
#    'normal_rate': 0.7407407407407407}),
#  ((34.8, -2.800000000000075),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 1,
#    'reset_rate': 0.037037037037037035,
#    'normal': 25,
#    'normal_rate': 0.9259259259259259}),
#  ((34.8, -5.200000000000076),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 26,
#    'normal_rate': 0.9629629629629629}),
#  ((34.8, -34.00000000000002),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 26,
#    'normal_rate': 0.9629629629629629}),
#  ((34.8, -34.40000000000002),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 26,
#    'normal_rate': 0.9629629629629629}),
#  ((34.8, -34.80000000000002),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 26,
#    'normal_rate': 0.9629629629629629}),
#  ((34.8, -35.20000000000002),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 26,
#    'normal_rate': 0.9629629629629629}),
#  ((34.8, -35.600000000000016),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 26,
#    'normal_rate': 0.9629629629629629}),
#  ((34.8, -36.000000000000014),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 26,
#    'normal_rate': 0.9629629629629629}),
#  ((34.8, -36.40000000000001),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 26,
#    'normal_rate': 0.9629629629629629}),
#  ((34.8, -36.80000000000001),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 26,
#    'normal_rate': 0.9629629629629629}),
#  ((34.8, -37.20000000000001),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 26,
#    'normal_rate': 0.9629629629629629}),
#  ((34.8, -37.60000000000001),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 26,
#    'normal_rate': 0.9629629629629629}),
#  ((34.8, -38.400000000000006),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 26,
#    'normal_rate': 0.9629629629629629}),
#  ((34.8, -39.2),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 26,
#    'normal_rate': 0.9629629629629629}),
#  ((34.8, -39.6),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 26,
#    'normal_rate': 0.9629629629629629}),
#  ((34.8, -40),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 26,
#    'normal_rate': 0.9629629629629629}),
#  ((34.4, 9.199999999999928),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 11,
#    'reset_rate': 0.4074074074074074,
#    'normal': 15,
#    'normal_rate': 0.5555555555555556}),
#  ((34.4, 6.399999999999927),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 12,
#    'reset_rate': 0.4444444444444444,
#    'normal': 14,
#    'normal_rate': 0.5185185185185185}),
#  ((34.4, 4.399999999999925),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 12,
#    'reset_rate': 0.4444444444444444,
#    'normal': 14,
#    'normal_rate': 0.5185185185185185}),
#  ((34.4, 2.7999999999999248),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 11,
#    'reset_rate': 0.4074074074074074,
#    'normal': 15,
#    'normal_rate': 0.5555555555555556}),
#  ((34.4, 2.399999999999925),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 10,
#    'reset_rate': 0.37037037037037035,
#    'normal': 16,
#    'normal_rate': 0.5925925925925926}),
#  ((34.4, 0.39999999999992486),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 3,
#    'reset_rate': 0.1111111111111111,
#    'normal': 23,
#    'normal_rate': 0.8518518518518519}),
#  ((34.4, -36.80000000000001),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 26,
#    'normal_rate': 0.9629629629629629}),
#  ((34.4, -37.60000000000001),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 1,
#    'reset_rate': 0.037037037037037035,
#    'normal': 25,
#    'normal_rate': 0.9259259259259259}),
#  ((34, 9.999999999999929),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 4,
#    'reset_rate': 0.14814814814814814,
#    'normal': 22,
#    'normal_rate': 0.8148148148148148}),
#  ((34, 8.799999999999928),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 6,
#    'reset_rate': 0.2222222222222222,
#    'normal': 20,
#    'normal_rate': 0.7407407407407407}),
#  ((34, 7.999999999999928),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 7,
#    'reset_rate': 0.25925925925925924,
#    'normal': 19,
#    'normal_rate': 0.7037037037037037}),
#  ((34, 5.999999999999926),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 9,
#    'reset_rate': 0.3333333333333333,
#    'normal': 17,
#    'normal_rate': 0.6296296296296297}),
#  ((34, 5.599999999999926),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 9,
#    'reset_rate': 0.3333333333333333,
#    'normal': 17,
#    'normal_rate': 0.6296296296296297}),
#  ((34, 5.199999999999926),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 8,
#    'reset_rate': 0.2962962962962963,
#    'normal': 18,
#    'normal_rate': 0.6666666666666666}),
#  ((34, 4.399999999999925),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 10,
#    'reset_rate': 0.37037037037037035,
#    'normal': 16,
#    'normal_rate': 0.5925925925925926}),
#  ((34, 3.9999999999999245),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 8,
#    'reset_rate': 0.2962962962962963,
#    'normal': 18,
#    'normal_rate': 0.6666666666666666}),
#  ((34, 3.5999999999999246),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 7,
#    'reset_rate': 0.25925925925925924,
#    'normal': 19,
#    'normal_rate': 0.7037037037037037}),
#  ((34, 2.7999999999999248),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 4,
#    'reset_rate': 0.14814814814814814,
#    'normal': 22,
#    'normal_rate': 0.8148148148148148}),
#  ((34, 2.399999999999925),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 4,
#    'reset_rate': 0.14814814814814814,
#    'normal': 22,
#    'normal_rate': 0.8148148148148148}),
#  ((34, 1.599999999999925),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 2,
#    'reset_rate': 0.07407407407407407,
#    'normal': 24,
#    'normal_rate': 0.8888888888888888}),
#  ((34, 1.199999999999925),
#   {'total': 27,
#    'success': 1,
#    'success_rate': 0.037037037037037035,
#    'reset': 1,
#    'reset_rate': 0.037037037037037035,
#    'normal': 25,
#    'normal_rate': 0.9259259259259259}),
#  ((35.99999999999999, 9.999999999999929),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 15,
#    'reset_rate': 0.5555555555555556,
#    'normal': 12,
#    'normal_rate': 0.4444444444444444}),
#  ((35.99999999999999, 9.599999999999929),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 15,
#    'reset_rate': 0.5555555555555556,
#    'normal': 12,
#    'normal_rate': 0.4444444444444444}),
#  ((35.99999999999999, 9.199999999999928),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 15,
#    'reset_rate': 0.5555555555555556,
#    'normal': 12,
#    'normal_rate': 0.4444444444444444}),
#  ((35.99999999999999, 8.799999999999928),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 15,
#    'reset_rate': 0.5555555555555556,
#    'normal': 12,
#    'normal_rate': 0.4444444444444444}),
#  ((35.99999999999999, 8.399999999999928),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 15,
#    'reset_rate': 0.5555555555555556,
#    'normal': 12,
#    'normal_rate': 0.4444444444444444}),
#  ((35.99999999999999, 7.999999999999928),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 15,
#    'reset_rate': 0.5555555555555556,
#    'normal': 12,
#    'normal_rate': 0.4444444444444444}),
#  ((35.99999999999999, 7.599999999999928),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 15,
#    'reset_rate': 0.5555555555555556,
#    'normal': 12,
#    'normal_rate': 0.4444444444444444}),
#  ((35.99999999999999, 7.199999999999927),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 16,
#    'reset_rate': 0.5925925925925926,
#    'normal': 11,
#    'normal_rate': 0.4074074074074074}),
#  ((35.99999999999999, 6.799999999999927),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 16,
#    'reset_rate': 0.5925925925925926,
#    'normal': 11,
#    'normal_rate': 0.4074074074074074}),
#  ((35.99999999999999, 6.399999999999927),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 16,
#    'reset_rate': 0.5925925925925926,
#    'normal': 11,
#    'normal_rate': 0.4074074074074074}),
#  ((35.99999999999999, 5.999999999999926),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 16,
#    'reset_rate': 0.5925925925925926,
#    'normal': 11,
#    'normal_rate': 0.4074074074074074}),
#  ((35.99999999999999, 5.599999999999926),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 17,
#    'reset_rate': 0.6296296296296297,
#    'normal': 10,
#    'normal_rate': 0.37037037037037035}),
#  ((35.99999999999999, 5.199999999999926),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 17,
#    'reset_rate': 0.6296296296296297,
#    'normal': 10,
#    'normal_rate': 0.37037037037037035}),
#  ((35.99999999999999, 4.799999999999925),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 17,
#    'reset_rate': 0.6296296296296297,
#    'normal': 10,
#    'normal_rate': 0.37037037037037035}),
#  ((35.99999999999999, 4.399999999999925),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 17,
#    'reset_rate': 0.6296296296296297,
#    'normal': 10,
#    'normal_rate': 0.37037037037037035}),
#  ((35.99999999999999, 3.9999999999999245),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 17,
#    'reset_rate': 0.6296296296296297,
#    'normal': 10,
#    'normal_rate': 0.37037037037037035}),
#  ((35.99999999999999, 3.5999999999999246),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 17,
#    'reset_rate': 0.6296296296296297,
#    'normal': 10,
#    'normal_rate': 0.37037037037037035}),
#  ((35.99999999999999, 3.1999999999999247),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 16,
#    'reset_rate': 0.5925925925925926,
#    'normal': 11,
#    'normal_rate': 0.4074074074074074}),
#  ((35.99999999999999, 2.7999999999999248),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 17,
#    'reset_rate': 0.6296296296296297,
#    'normal': 10,
#    'normal_rate': 0.37037037037037035}),
#  ((35.99999999999999, 2.399999999999925),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 16,
#    'reset_rate': 0.5925925925925926,
#    'normal': 11,
#    'normal_rate': 0.4074074074074074}),
#  ((35.99999999999999, 1.999999999999925),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 16,
#    'reset_rate': 0.5925925925925926,
#    'normal': 11,
#    'normal_rate': 0.4074074074074074}),
#  ((35.99999999999999, 1.599999999999925),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 16,
#    'reset_rate': 0.5925925925925926,
#    'normal': 11,
#    'normal_rate': 0.4074074074074074}),
#  ((35.99999999999999, 1.199999999999925),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 15,
#    'reset_rate': 0.5555555555555556,
#    'normal': 12,
#    'normal_rate': 0.4444444444444444}),
#  ((35.99999999999999, 0.7999999999999249),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 17,
#    'reset_rate': 0.6296296296296297,
#    'normal': 10,
#    'normal_rate': 0.37037037037037035}),
#  ((35.99999999999999, 0.39999999999992486),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 15,
#    'reset_rate': 0.5555555555555556,
#    'normal': 12,
#    'normal_rate': 0.4444444444444444}),
#  ((35.99999999999999, -7.51620987671231e-14),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 16,
#    'reset_rate': 0.5925925925925926,
#    'normal': 11,
#    'normal_rate': 0.4074074074074074}),
#  ((35.99999999999999, -0.4000000000000752),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 16,
#    'reset_rate': 0.5925925925925926,
#    'normal': 11,
#    'normal_rate': 0.4074074074074074}),
#  ((35.99999999999999, -0.8000000000000752),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 16,
#    'reset_rate': 0.5925925925925926,
#    'normal': 11,
#    'normal_rate': 0.4074074074074074}),
#  ((35.99999999999999, -1.2000000000000752),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 15,
#    'reset_rate': 0.5555555555555556,
#    'normal': 12,
#    'normal_rate': 0.4444444444444444}),
#  ((35.99999999999999, -1.6000000000000751),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 15,
#    'reset_rate': 0.5555555555555556,
#    'normal': 12,
#    'normal_rate': 0.4444444444444444}),
#  ((35.99999999999999, -2.000000000000075),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 15,
#    'reset_rate': 0.5555555555555556,
#    'normal': 12,
#    'normal_rate': 0.4444444444444444}),
#  ((35.99999999999999, -2.400000000000075),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 16,
#    'reset_rate': 0.5925925925925926,
#    'normal': 11,
#    'normal_rate': 0.4074074074074074}),
#  ((35.99999999999999, -2.800000000000075),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 15,
#    'reset_rate': 0.5555555555555556,
#    'normal': 12,
#    'normal_rate': 0.4444444444444444}),
#  ((35.99999999999999, -3.200000000000075),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 15,
#    'reset_rate': 0.5555555555555556,
#    'normal': 12,
#    'normal_rate': 0.4444444444444444}),
#  ((35.99999999999999, -3.6000000000000747),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 13,
#    'reset_rate': 0.48148148148148145,
#    'normal': 14,
#    'normal_rate': 0.5185185185185185}),
#  ((35.99999999999999, -4.400000000000075),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 14,
#    'reset_rate': 0.5185185185185185,
#    'normal': 13,
#    'normal_rate': 0.48148148148148145}),
#  ((35.99999999999999, -4.800000000000075),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 14,
#    'reset_rate': 0.5185185185185185,
#    'normal': 13,
#    'normal_rate': 0.48148148148148145}),
#  ((35.99999999999999, -5.200000000000076),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 11,
#    'reset_rate': 0.4074074074074074,
#    'normal': 16,
#    'normal_rate': 0.5925925925925926}),
#  ((35.99999999999999, -6.400000000000077),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 14,
#    'reset_rate': 0.5185185185185185,
#    'normal': 13,
#    'normal_rate': 0.48148148148148145}),
#  ((35.99999999999999, -6.800000000000077),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 13,
#    'reset_rate': 0.48148148148148145,
#    'normal': 14,
#    'normal_rate': 0.5185185185185185}),
#  ((35.99999999999999, -7.600000000000078),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 13,
#    'reset_rate': 0.48148148148148145,
#    'normal': 14,
#    'normal_rate': 0.5185185185185185}),
#  ((35.99999999999999, -8.000000000000078),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 12,
#    'reset_rate': 0.4444444444444444,
#    'normal': 15,
#    'normal_rate': 0.5555555555555556}),
#  ((35.99999999999999, -9.20000000000008),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 11,
#    'reset_rate': 0.4074074074074074,
#    'normal': 16,
#    'normal_rate': 0.5925925925925926}),
#  ((35.99999999999999, -11.600000000000081),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 11,
#    'reset_rate': 0.4074074074074074,
#    'normal': 16,
#    'normal_rate': 0.5925925925925926}),
#  ((35.99999999999999, -12.400000000000082),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 9,
#    'reset_rate': 0.3333333333333333,
#    'normal': 18,
#    'normal_rate': 0.6666666666666666}),
#  ((35.99999999999999, -12.800000000000082),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 12,
#    'reset_rate': 0.4444444444444444,
#    'normal': 15,
#    'normal_rate': 0.5555555555555556}),
#  ((35.99999999999999, -13.200000000000083),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 9,
#    'reset_rate': 0.3333333333333333,
#    'normal': 18,
#    'normal_rate': 0.6666666666666666}),
#  ((35.99999999999999, -14.000000000000083),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 8,
#    'reset_rate': 0.2962962962962963,
#    'normal': 19,
#    'normal_rate': 0.7037037037037037}),
#  ((35.99999999999999, -14.800000000000084),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 10,
#    'reset_rate': 0.37037037037037035,
#    'normal': 17,
#    'normal_rate': 0.6296296296296297}),
#  ((35.99999999999999, -17.60000000000008),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((35.99999999999999, -18.000000000000078),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((35.99999999999999, -18.400000000000077),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((35.99999999999999, -18.800000000000075),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((35.99999999999999, -19.200000000000074),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((35.99999999999999, -19.600000000000072),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((35.99999999999999, -20.00000000000007),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((35.99999999999999, -20.40000000000007),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((35.99999999999999, -20.800000000000068),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((35.99999999999999, -21.200000000000067),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((35.99999999999999, -21.600000000000065),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((35.99999999999999, -22.000000000000064),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((35.99999999999999, -22.400000000000063),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((35.99999999999999, -22.80000000000006),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((35.99999999999999, -23.20000000000006),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((35.99999999999999, -23.60000000000006),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((35.99999999999999, -24.000000000000057),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((35.99999999999999, -24.400000000000055),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((35.99999999999999, -24.800000000000054),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((35.99999999999999, -25.200000000000053),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((35.99999999999999, -25.60000000000005),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((35.99999999999999, -26.00000000000005),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((35.99999999999999, -26.40000000000005),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((35.99999999999999, -26.800000000000047),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((35.99999999999999, -27.200000000000045),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((35.99999999999999, -27.600000000000044),
#   {'total': 27,
# ...
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -1.6000000000000751),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -2.000000000000075),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -2.400000000000075),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -2.800000000000075),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -3.200000000000075),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -3.6000000000000747),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -4.000000000000075),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -4.400000000000075),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -4.800000000000075),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -5.200000000000076),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -5.600000000000076),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -6.000000000000076),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -6.400000000000077),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -6.800000000000077),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -7.2000000000000774),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -7.600000000000078),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -8.000000000000078),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -8.400000000000079),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -8.800000000000079),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -9.20000000000008),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -9.60000000000008),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -10.00000000000008),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -10.40000000000008),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -10.80000000000008),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -11.200000000000081),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -11.600000000000081),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -12.000000000000082),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -12.400000000000082),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -12.800000000000082),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -13.200000000000083),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -13.600000000000083),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -14.000000000000083),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -14.400000000000084),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -14.800000000000084),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -15.200000000000085),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -15.600000000000085),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -16.000000000000085),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -16.400000000000084),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -16.800000000000082),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -17.20000000000008),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -17.60000000000008),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -18.000000000000078),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -18.400000000000077),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -18.800000000000075),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -19.200000000000074),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -19.600000000000072),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -20.00000000000007),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -20.40000000000007),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -20.800000000000068),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -21.200000000000067),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -21.600000000000065),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -22.000000000000064),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -22.400000000000063),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -22.80000000000006),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -23.20000000000006),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -23.60000000000006),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -24.000000000000057),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -24.400000000000055),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -24.800000000000054),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -25.200000000000053),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -25.60000000000005),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -26.00000000000005),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -26.40000000000005),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -26.800000000000047),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -27.200000000000045),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -27.600000000000044),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -28.000000000000043),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -28.40000000000004),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -28.80000000000004),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -29.20000000000004),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -29.600000000000037),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -30.000000000000036),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -30.400000000000034),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -30.800000000000033),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -31.20000000000003),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -31.60000000000003),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -32.00000000000003),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -32.40000000000003),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -32.800000000000026),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -33.200000000000024),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -33.60000000000002),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -34.00000000000002),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -34.40000000000002),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -34.80000000000002),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -35.20000000000002),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -35.600000000000016),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -36.000000000000014),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -36.40000000000001),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -36.80000000000001),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -37.20000000000001),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -37.60000000000001),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -38.00000000000001),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -38.400000000000006),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -38.800000000000004),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -39.2),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -39.6),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0}),
#  ((34, -40),
#   {'total': 27,
#    'success': 0,
#    'success_rate': 0.0,
#    'reset': 0,
#    'reset_rate': 0.0,
#    'normal': 27,
#    'normal_rate': 1.0})]

# %%
gc.plot_2d(alpha=False)
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='20408452-72b2-442e-8386-2a0c4a8dbb9a'>
#   <div id="ad3fd146-ded9-4304-a6b2-83934932863e" data-root-id="20408452-72b2-442e-8386-2a0c4a8dbb9a" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"e247d696-585b-412b-82bd-4541b17d8cbf":{"version":"3.6.3","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"20408452-72b2-442e-8386-2a0c4a8dbb9a"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"47008f34-41ad-498a-a3d7-c8fe8407ed91","attributes":{"plot_id":"20408452-72b2-442e-8386-2a0c4a8dbb9a","comm_id":"7478b2dce809478585f2f7f9bbc71e3b","client_comm_id":"822c87b67d8a4fd285bfa25ec85d3269"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_rendered","kind":"Any","default":false},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","d ...
#   var render_items = [{"docid":"e247d696-585b-412b-82bd-4541b17d8cbf","roots":{"20408452-72b2-442e-8386-2a0c4a8dbb9a":"ad3fd146-ded9-4304-a6b2-83934932863e"},"root_ids":["20408452-72b2-442e-8386-2a0c4a8dbb9a"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# [0, 1, 2, 3]
# ['width', 'offset']
# (34, -40)
# :Overlay
#    .Points.I       :Points   [Width,Offset]
#    .Points.Success :Points   [width,offset]   (success_rate)
#    .Points.Reset   :Points   [width,offset]   (reset_rate)

# %%
scope.dis()
target.dis()

# %%
assert total_successes >= 1
